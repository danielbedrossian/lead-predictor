# %% [markdown]
# # Abstract & Imports

# %% [markdown]
# Abstract:
#
# This notebook explores the use of the Random Forest Classifier model within a sales team of a B2B SaaS company. Sales teams leverage huge amounts of data regarding current clients and prospective clients/leads, this notebook intends to leverage subsets of that data to make predictions on which leads/prospects would be most worthwhile to pursue. The practical application of this model would assist in lowering workloads of sales teams and thinning the collection of leads to focus on more attainable prospects.
#
# Note: All datasets used in this notebook have been simulated. The primary goal of this notebook is to showcase a proof of concept for the model.

# %%
import os
import time
from datetime import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn

import statsmodels.api as sm

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.getcwd()
# Out:
# '/content'

# %%
data_path = '/content/drive/MyDrive/Colab Notebooks/Customer Predictor/Data'

# %% [markdown]
# # A Look at the Data

# %% [markdown]
# client_leads_list.csv contains each lead that our sales team has acted upon.
#
# The columns contain information as follows:
# *    Company Industry: The industry that the company works in
# *    Employee Count: The number of employees working for the company
# *    Company HQ Location: The location of the company's HQ
# *    Year Founded: The year the company was founded
# *    POC Title: The title of the point of contact for the lead
# *    Method of Sourcing: Wether this was an inbound lead or outbound
# *    Client: Whether this lead was converted into a customer or not
# *    Train/Test: Whether this row should be included in the models Training or Testing

# %%
leads_list = pd.read_csv(os.path.join(data_path, 'client_leads_list.csv'))

# %%
leads_list
# Out:
#         Company Industry Employee Count Company HQ Location  Year Founded  \
# 0                 Sports         11-100     Los Angeles, CA          2019
# 1             Technology         11-100     Los Angeles, CA          2017
# 2    Media/Entertainment         11-100         Seattle, WA          2020
# 3              Ecommerce        101-500   San Fransisco, CA          2017
# 4             Consulting           1-10         Chicago, IL          2016
# ..                   ...            ...                 ...           ...
# 294           Technology         11-100     Los Angeles, CA          2011
# 295            Ecommerce         11-100     Los Angeles, CA          2020
# 296            Ecommerce         11-100   New York City, NY          2012
# 297            Ecommerce           1-10   New York City, NY          2021
# 298          Real Estate        101-500     Los Angeles, CA          2012
#
#                  POC Title Method of Sourcing  Client Train/Test
# 0           Senior Manager            Inbound       0      Train
# 1                President           Outbound       0      Train
# 2                President           Outbound       0      Train
# 3                President           Outbound       1      Train
# 4                  Manager           Outbound       1      Train
# ..                     ...                ...     ...        ...
# 294                Manager           Outbound       0       Test
# 295  Senior Vice President            Inbound       1       Test
# 296          Founder & CEO           Outbound       0       Test
# 297         Vice President           Outbound       0       Test
# 298         Senior Manager           Outbound       0       Test
#
# [299 rows x 8 columns]

# %%
leads_list.dtypes
# Out:
# Company Industry       object
# Employee Count         object
# Company HQ Location    object
# Year Founded            int64
# POC Title              object
# Method of Sourcing     object
# Client                  int64
# Train/Test             object
# dtype: object

# %%
#The random forest classifier can only work with ints/floats so we need to convert our variables
leads_list['industry_code'] = leads_list['Company Industry'].astype('category').cat.codes
leads_list['num_employees_code'] = leads_list['Employee Count'].astype('category').cat.codes
leads_list['location_code'] = leads_list['Company HQ Location'].astype('category').cat.codes
leads_list['title_code'] = leads_list['POC Title'].astype('category').cat.codes
leads_list['source_code'] = leads_list['Method of Sourcing'].astype('category').cat.codes
leads_list
# Out:
#         Company Industry Employee Count Company HQ Location  Year Founded  \
# 0                 Sports         11-100     Los Angeles, CA          2019
# 1             Technology         11-100     Los Angeles, CA          2017
# 2    Media/Entertainment         11-100         Seattle, WA          2020
# 3              Ecommerce        101-500   San Fransisco, CA          2017
# 4             Consulting           1-10         Chicago, IL          2016
# ..                   ...            ...                 ...           ...
# 294           Technology         11-100     Los Angeles, CA          2011
# 295            Ecommerce         11-100     Los Angeles, CA          2020
# 296            Ecommerce         11-100   New York City, NY          2012
# 297            Ecommerce           1-10   New York City, NY          2021
# 298          Real Estate        101-500     Los Angeles, CA          2012
#
#                  POC Title Method of Sourcing  Client Train/Test  \
# 0           Senior Manager            Inbound       0      Train
# 1                President           Outbound       0      Train
# 2                President           Outbound       0      Train
# 3                President           Outbound       1      Train
# 4                  Manager           Outbound       1      Train
# ..                     ...                ...     ...        ...
# 294                Manager           Outbound       0       Test
# 295  Senior Vice President            Inbound       1       Test
# 296          Founder & CEO           Outbound       0       Test
# 297         Vice President           Outbound       0       Test
# 298         Senior Manager           Outbound       0       Test
#
#      industry_code  num_employees_code  location_code  title_code  source_code
# 0               13                   2              3           9            0
# 1               14                   2              3           7            1
# 2               10                   2              7           7            1
# 3                2                   1              6           7            1
# 4                1                   0              2           6            1
# ..             ...                 ...            ...         ...          ...
# 294             14                   2              3           6            1
# 295              2                   2              3          10            0
# 296              2                   2              5           5            1
# 297              2                   0              5          11            1
# 298             12                   1              3           9            1
#
# [299 rows x 13 columns]

# %% [markdown]
# # Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=50,\
                            min_samples_split=10,\
                            random_state=448)

train = leads_list[leads_list['Train/Test'] == 'Train']

test = leads_list[leads_list['Train/Test'] == 'Test']

predictors = ['Year Founded', 'industry_code', 'num_employees_code', 'location_code', 'title_code', 'source_code']

# %%
rf.fit(train[predictors], train['Client'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=448)

# %%
preds = rf.predict(test[predictors])

# %%
#We want to ensure our accuracy and precision are decent before using it to predict
from sklearn.metrics import accuracy_score

acc = accuracy_score(test['Client'], preds)

acc
# Out:
# 0.75

# %%
from sklearn.metrics import precision_score

precision_score(test['Client'], preds)
# Out:
# 0.6470588235294118

# %% [markdown]
# # Prediction

# %% [markdown]
# leads_list_needs_prediction.csv contains 100 data points for leads that our sales team has yet to act on. We are going to put it through our model and see which leads it tells us to act upon.
#
# The columns are the exact same as our previous dataset.

# %%
prospect_list = pd.read_csv(os.path.join(data_path, 'leads_list_needs_prediction.csv'))
prospect_list
# Out:
#    Company Industry Employee Count Company HQ Location  Year Founded  \
# 0   Food & Beverage           1-10     Los Angeles, CA          2012
# 1         Ecommerce       501-1000         Seattle, WA          2021
# 2        Consulting         11-100     Los Angeles, CA          2023
# 3         Ecommerce           1-10     Los Angeles, CA          2009
# 4        Technology           1-10   New York City, NY          2013
# ..              ...            ...                 ...           ...
# 95       Consulting         11-100     Los Angeles, CA          2013
# 96       Consulting         11-100     Los Angeles, CA          2015
# 97        Ecommerce         11-100     Los Angeles, CA          2014
# 98        Ecommerce         11-100          Boston, MA          2018
# 99        Marketing           1-10     Los Angeles, CA          2023
#
#                 POC Title Method of Sourcing
# 0                 Manager           Outbound
# 1   Senior Vice President           Outbound
# 2                 Manager           Outbound
# 3                     COO           Outbound
# 4                Director           Outbound
# ..                    ...                ...
# 95                    COO           Outbound
# 96         Vice President           Outbound
# 97                    COO           Outbound
# 98              President           Outbound
# 99         Senior Manager           Outbound
#
# [100 rows x 6 columns]

# %%
prospect_list.dtypes
# Out:
# Company Industry       object
# Employee Count         object
# Company HQ Location    object
# Year Founded            int64
# POC Title              object
# Method of Sourcing     object
# dtype: object

# %%
prospect_list['industry_code'] = prospect_list['Company Industry'].astype('category').cat.codes
prospect_list['num_employees_code'] = prospect_list['Employee Count'].astype('category').cat.codes
prospect_list['location_code'] = prospect_list['Company HQ Location'].astype('category').cat.codes
prospect_list['title_code'] = prospect_list['POC Title'].astype('category').cat.codes
prospect_list['source_code'] = prospect_list['Method of Sourcing'].astype('category').cat.codes
prospect_list
# Out:
#    Company Industry Employee Count Company HQ Location  Year Founded  \
# 0   Food & Beverage           1-10     Los Angeles, CA          2012
# 1         Ecommerce       501-1000         Seattle, WA          2021
# 2        Consulting         11-100     Los Angeles, CA          2023
# 3         Ecommerce           1-10     Los Angeles, CA          2009
# 4        Technology           1-10   New York City, NY          2013
# ..              ...            ...                 ...           ...
# 95       Consulting         11-100     Los Angeles, CA          2013
# 96       Consulting         11-100     Los Angeles, CA          2015
# 97        Ecommerce         11-100     Los Angeles, CA          2014
# 98        Ecommerce         11-100          Boston, MA          2018
# 99        Marketing           1-10     Los Angeles, CA          2023
#
#                 POC Title Method of Sourcing  industry_code  \
# 0                 Manager           Outbound              6
# 1   Senior Vice President           Outbound              2
# 2                 Manager           Outbound              1
# 3                     COO           Outbound              2
# 4                Director           Outbound             13
# ..                    ...                ...            ...
# 95                    COO           Outbound              1
# 96         Vice President           Outbound              1
# 97                    COO           Outbound              2
# 98              President           Outbound              2
# 99         Senior Manager           Outbound              8
#
#     num_employees_code  location_code  title_code  source_code
# 0                    0              3           6            1
# 1                    4              6           9            1
# 2                    3              3           6            1
# 3                    0              3           2            1
# 4                    0              4           4            1
# ..                 ...            ...         ...          ...
# 95                   3              3           2            1
# 96                   3              3          10            1
# 97                   3              3           2            1
# 98                   3              1           7            1
# 99                   0              3           8            1
#
# [100 rows x 11 columns]

# %%
predictors = ['Year Founded', 'industry_code', 'num_employees_code', 'location_code', 'title_code', 'source_code']

prospect_list['Predicted Outcome'] = rf.predict(prospect_list[predictors])

prospect_list
# Out:
#    Company Industry Employee Count Company HQ Location  Year Founded  \
# 0   Food & Beverage           1-10     Los Angeles, CA          2012
# 1         Ecommerce       501-1000         Seattle, WA          2021
# 2        Consulting         11-100     Los Angeles, CA          2023
# 3         Ecommerce           1-10     Los Angeles, CA          2009
# 4        Technology           1-10   New York City, NY          2013
# ..              ...            ...                 ...           ...
# 95       Consulting         11-100     Los Angeles, CA          2013
# 96       Consulting         11-100     Los Angeles, CA          2015
# 97        Ecommerce         11-100     Los Angeles, CA          2014
# 98        Ecommerce         11-100          Boston, MA          2018
# 99        Marketing           1-10     Los Angeles, CA          2023
#
#                 POC Title Method of Sourcing  industry_code  \
# 0                 Manager           Outbound              6
# 1   Senior Vice President           Outbound              2
# 2                 Manager           Outbound              1
# 3                     COO           Outbound              2
# 4                Director           Outbound             13
# ..                    ...                ...            ...
# 95                    COO           Outbound              1
# 96         Vice President           Outbound              1
# 97                    COO           Outbound              2
# 98              President           Outbound              2
# 99         Senior Manager           Outbound              8
#
#     num_employees_code  location_code  title_code  source_code  \
# 0                    0              3           6            1
# 1                    4              6           9            1
# 2                    3              3           6            1
# 3                    0              3           2            1
# 4                    0              4           4            1
# ..                 ...            ...         ...          ...
# 95                   3              3           2            1
# 96                   3              3          10            1
# 97                   3              3           2            1
# 98                   3              1           7            1
# 99                   0              3           8            1
#
#     Predicted Outcome
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 95                  0
# 96                  0
# 97                  0
# 98                  0
# 99                  0
#
# [100 rows x 12 columns]

# %%
#The subset of leads that our model tells us are worthy for our sales team to act upon
prospect_list[prospect_list['Predicted Outcome'] == 1]
# Out:
#        Company Industry Employee Count Company HQ Location  Year Founded  \
# 13            Ecommerce           1-10     Los Angeles, CA          2006
# 14              Finance         11-100     Los Angeles, CA          2021
# 17           Consulting           1-10         Chicago, IL          2017
# 22           Consulting           1-10         Chicago, IL          2012
# 30            Ecommerce           1-10     Los Angeles, CA          2020
# 31            Ecommerce         11-100     Los Angeles, CA          2022
# 36            Marketing           1-10     Los Angeles, CA          2018
# 45           Consulting           1-10     Los Angeles, CA          2021
# 48            Ecommerce           1-10     Los Angeles, CA          2020
# 52            Ecommerce           1-10   San Fransisco, CA          2022
# 60           Consulting         11-100     Los Angeles, CA          2022
# 61       Pharmacuetical         11-100         Seattle, WA          2014
# 66               Energy         11-100     Los Angeles, CA          2011
# 70           Consulting          1000+     Los Angeles, CA          2023
# 73       Pharmacuetical         11-100     Los Angeles, CA          2022
# 80               Sports         11-100         Chicago, IL          2020
# 84           Technology         11-100   New York City, NY          2014
# 87  Media/Entertainment           1-10     Los Angeles, CA          2016
#
#          POC Title Method of Sourcing  industry_code  num_employees_code  \
# 13        Director           Outbound              2                   0
# 14             COO            Inbound              5                   3
# 17        Director            Inbound              1                   0
# 22  Senior Manager            Inbound              1                   0
# 30             COO           Outbound              2                   0
# 31         Manager            Inbound              2                   3
# 36             COO            Inbound              8                   0
# 45  Senior Manager           Outbound              1                   0
# 48             COO           Outbound              2                   0
# 52        Director           Outbound              2                   0
# 60  Vice President            Inbound              1                   3
# 61     Coordinator            Inbound             10                   3
# 66     Coordinator            Inbound              4                   3
# 70  Senior Manager           Outbound              1                   1
# 73  Vice President            Inbound             10                   3
# 80   Founder & CEO            Inbound             12                   3
# 84  Senior Manager            Inbound             13                   3
# 87             COO           Outbound              9                   0
#
#     location_code  title_code  source_code  Predicted Outcome
# 13              3           4            1                  1
# 14              3           2            0                  1
# 17              2           4            0                  1
# 22              2           8            0                  1
# 30              3           2            1                  1
# 31              3           6            0                  1
# 36              3           2            0                  1
# 45              3           8            1                  1
# 48              3           2            1                  1
# 52              5           4            1                  1
# 60              3          10            0                  1
# 61              6           3            0                  1
# 66              3           3            0                  1
# 70              3           8            1                  1
# 73              3          10            0                  1
# 80              2           5            0                  1
# 84              4           8            0                  1
# 87              3           2            1                  1

# %% [markdown]
# # Pitfalls & Areas of Improvement/Exploration

# %% [markdown]
# The most obvious area for improvement would be in using actual real world data instead of simulated data to understand if this model would be beneficial for an actual sales team to employ.
#
# Considering our model gave returned 18% of leads as worthwhile to pursue it is clear we need to worry about Type 2 errors within the model. Any company cannot afford to leave money of the table in this instance. It would be wise to correct for these errors especially.
#
# It may be more ideal to consider a different ML algorithm such as Decision Trees/K-Means, etc. instead of Random Forest Classifier.
